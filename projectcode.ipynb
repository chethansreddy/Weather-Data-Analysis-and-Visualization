# %% [markdown]
# ## Weather Data  ANALYSIS and VISUALIZATION using pandas, matplotlib and seaborn

# %% [markdown]
# ### 1.Importing necessary libraries

# %%
#to perform numerical operations 
import numpy as np

# %%
#to work with dataframe
import pandas as pd

# %%
#for graphical plotting 
import matplotlib as mpl

# %%
import matplotlib.pyplot as plt

# %%
#for data analysis and exploratory data analysis 
import seaborn as sns

# %%
#reading data into python 
data = pd.read_csv('C:/Users/chakr/Downloads/weather.csv',)

# %% [markdown]
# ### 2. Data cleaning and Analysis

# %%
#getting first 5 columns of data 
data.head()
# Out:
#         PDT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0  9/1/2015                75                 67                58
# 1  9/2/2015                73                 68                62
# 2  9/3/2015                70                 65                60
# 3  9/4/2015                72                 64                55
# 4  9/5/2015                79                 65                51
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0              58              56             54            84
# 1              59              56             54            78
# 2              57              54             50            84
# 3              52              50             48            77
# 4              53              48             44            89
#
#     Mean Humidity   Min Humidity  ...   Mean VisibilityMiles  \
# 0              67             49  ...                   10.0
# 1              68             57  ...                   10.0
# 2              69             53  ...                   10.0
# 3              61             44  ...                   10.0
# 4              60             30  ...                   10.0
#
#     Min VisibilityMiles   Max Wind SpeedMPH   Mean Wind SpeedMPH  \
# 0                   6.0                  22                    9
# 1                  10.0                  23                   12
# 2                  10.0                  18                   12
# 3                   7.0                  20                   10
# 4                  10.0                  21                    7
#
#     Max Gust SpeedMPH  PrecipitationIn   CloudCover   Events   WindDirDegrees  \
# 0                26.0                0            2      NaN              245
# 1                26.0                0            5      NaN              249
# 2                25.0                0            2      NaN              250
# 3                24.0                0            2      NaN              233
# 4                24.0                0            2      NaN              289
#
#      ZIP
# 0  94107
# 1  94107
# 2  94107
# 3  94107
# 4  94107
#
# [5 rows x 24 columns]

# %%
#to check variables data types
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1830 entries, 0 to 1829
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PDT                         1830 non-null   object
#  1   Max TemperatureF            1830 non-null   int64
#  2   Mean TemperatureF           1830 non-null   int64
#  3   Min TemperatureF            1830 non-null   int64
#  4   Max Dew PointF              1830 non-null   int64
#  5   MeanDew PointF              1830 non-null   int64
#  6   Min DewpointF               1830 non-null   int64
#  7   Max Humidity                1830 non-null   int64
#  8    Mean Humidity              1830 non-null   int64
#  9    Min Humidity               1830 non-null   int64
#  10   Max Sea Level PressureIn   1830 non-null   float64
#  11   Mean Sea Level PressureIn  1830 non-null   float64
#  12   Min Sea Level PressureIn   1830 non-null   float64
#  13   Max VisibilityMiles        1821 non-null   float64
#  14   Mean VisibilityMiles       1821 non-null   float64
#  15   Min VisibilityMiles        1821 non-null   float64
#  16   Max Wind SpeedMPH          1830 non-null   int64
#  17   Mean Wind SpeedMPH         1830 non-null   int64
#  18   Max Gust SpeedMPH          1294 non-null   float64
#  19  PrecipitationIn             1830 non-null   object
#  20   CloudCover                 1830 non-null   int64
#  21   Events                     366 non-null    object
#  22   WindDirDegrees             1830 non-null   int64
#  23  ZIP                         1830 non-null   int64
# dtypes: float64(7), int64(14), object(3)
# memory usage: 343.2+ KB
# None

# %%
#checking for missing values
data.isnull()
# Out:
#         PDT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0     False             False              False             False
# 1     False             False              False             False
# 2     False             False              False             False
# 3     False             False              False             False
# 4     False             False              False             False
# ...     ...               ...                ...               ...
# 1825  False             False              False             False
# 1826  False             False              False             False
# 1827  False             False              False             False
# 1828  False             False              False             False
# 1829  False             False              False             False
#
#       Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0              False           False          False         False
# 1              False           False          False         False
# 2              False           False          False         False
# 3              False           False          False         False
# 4              False           False          False         False
# ...              ...             ...            ...           ...
# 1825           False           False          False         False
# 1826           False           False          False         False
# 1827           False           False          False         False
# 1828           False           False          False         False
# 1829           False           False          False         False
#
#        Mean Humidity   Min Humidity  ...   Mean VisibilityMiles  \
# 0              False          False  ...                  False
# 1              False          False  ...                  False
# 2              False          False  ...                  False
# 3              False          False  ...                  False
# 4              False          False  ...                  False
# ...              ...            ...  ...                    ...
# 1825           False          False  ...                  False
# 1826           False          False  ...                  False
# 1827           False          False  ...                  False
# 1828           False          False  ...                  False
# 1829           False          False  ...                  False
#
#        Min VisibilityMiles   Max Wind SpeedMPH   Mean Wind SpeedMPH  \
# 0                    False               False                False
# 1                    False               False                False
# 2                    False               False                False
# 3                    False               False                False
# 4                    False               False                False
# ...                    ...                 ...                  ...
# 1825                 False               False                False
# 1826                 False               False                False
# 1827                 False               False                False
# 1828                 False               False                False
# 1829                 False               False                False
#
#        Max Gust SpeedMPH  PrecipitationIn   CloudCover   Events  \
# 0                  False            False        False     True
# 1                  False            False        False     True
# 2                  False            False        False     True
# 3                  False            False        False     True
# 4                  False            False        False     True
# ...                  ...              ...          ...      ...
# 1825               False            False        False     True
# 1826               False            False        False     True
# 1827               False            False        False     True
# 1828               False            False        False     True
# 1829               False            False        False     True
#
#        WindDirDegrees    ZIP
# 0               False  False
# 1               False  False
# 2               False  False
# 3               False  False
# 4               False  False
# ...               ...    ...
# 1825            False  False
# 1826            False  False
# 1827            False  False
# 1828            False  False
# 1829            False  False
#
# [1830 rows x 24 columns]

# %%
#number of missing values
data.isnull().sum()
# Out:
# PDT                              0
# Max TemperatureF                 0
# Mean TemperatureF                0
# Min TemperatureF                 0
# Max Dew PointF                   0
# MeanDew PointF                   0
# Min DewpointF                    0
# Max Humidity                     0
#  Mean Humidity                   0
#  Min Humidity                    0
#  Max Sea Level PressureIn        0
#  Mean Sea Level PressureIn       0
#  Min Sea Level PressureIn        0
#  Max VisibilityMiles             9
#  Mean VisibilityMiles            9
#  Min VisibilityMiles             9
#  Max Wind SpeedMPH               0
#  Mean Wind SpeedMPH              0
#  Max Gust SpeedMPH             536
# PrecipitationIn                  0
#  CloudCover                      0
#  Events                       1464
#  WindDirDegrees                  0
# ZIP                              0
# dtype: int64

# %%
#summary of numerical variables 
summary_num = data.describe()
print(summary_num)
# Out:
#        Max TemperatureF  Mean TemperatureF  Min TemperatureF  Max Dew PointF  \
# count       1830.000000        1830.000000       1830.000000     1830.000000
# mean          70.143169          61.218033         51.965574       53.584153
# std            9.593330           7.579865          6.974563        6.147118
# min           46.000000          32.000000          1.000000       26.000000
# 25%           63.000000          56.000000         48.000000       50.000000
# 50%           70.000000          62.000000         53.000000       55.000000
# 75%           77.000000          67.000000         57.000000       58.000000
# max          134.000000          94.000000         69.000000       66.000000
#
#        MeanDew PointF  Min DewpointF  Max Humidity   Mean Humidity  \
# count     1830.000000    1830.000000   1830.000000     1830.000000
# mean        49.482514      45.159563     86.536066       68.627322
# std          6.619509       7.787480      8.479129       10.538529
# min         21.000000       5.000000     46.000000       29.000000
# 25%         46.000000      41.000000     82.000000       63.000000
# 50%         51.000000      46.000000     87.000000       69.000000
# 75%         54.000000      51.000000     93.000000       76.000000
# max         62.000000      59.000000    100.000000       97.000000
#
#         Min Humidity   Max Sea Level PressureIn  ...  \
# count    1830.000000                1830.000000  ...
# mean       48.457377                  30.081913  ...
# std        14.077816                   0.138126  ...
# min         6.000000                  29.670000  ...
# 25%        40.000000                  29.980000  ...
# 50%        49.000000                  30.060000  ...
# 75%        57.000000                  30.170000  ...
# max        93.000000                  30.490000  ...
#
#         Min Sea Level PressureIn   Max VisibilityMiles   Mean VisibilityMiles  \
# count                1830.000000           1821.000000            1821.000000
# mean                   29.970973             10.140033               9.713893
# std                     0.141502              1.096771               0.943438
# min                    29.460000             10.000000               4.000000
# 25%                    29.880000             10.000000              10.000000
# 50%                    29.960000             10.000000              10.000000
# 75%                    30.060000             10.000000              10.000000
# max                    30.380000             20.000000              17.000000
#
#         Min VisibilityMiles   Max Wind SpeedMPH   Mean Wind SpeedMPH  \
# count           1821.000000         1830.000000          1830.000000
# mean               8.220209           16.490710             6.499454
# std                2.850361            6.137184             3.273358
# min                0.000000            0.000000             0.000000
# 25%                7.000000           13.000000             4.000000
# 50%               10.000000           16.000000             6.000000
# 75%               10.000000           20.000000             8.000000
# max               10.000000          115.000000            22.000000
#
#         Max Gust SpeedMPH   CloudCover   WindDirDegrees           ZIP
# count         1294.000000  1830.000000      1830.000000   1830.000000
# mean            22.040185     3.084699       261.172131  94325.000000
# std              5.923717     2.369603        93.139856    404.670589
# min              8.000000     0.000000        -1.000000  94041.000000
# 25%             18.000000     1.000000       233.000000  94063.000000
# 50%             22.000000     3.000000       295.000000  94107.000000
# 75%             25.000000     5.000000       326.000000  94301.000000
# max             46.000000     8.000000       360.000000  95113.000000
#
# [8 rows x 21 columns]

# %%
#summary of categorical variables 
summary_cate = data.describe(include = 'O')
print(summary_cate)
# Out:
#               PDT PrecipitationIn  Events
# count        1830            1830     366
# unique        366              64       4
# top     9/16/2015               0    Rain
# freq            5            1533     299

# %%
#frequency of ' Events'
data[' Events'].value_counts()
# Out:
# Rain                 299
# Fog                   49
# Fog-Rain               9
# Rain-Thunderstorm      9
# Name:  Events, dtype: int64

# %%
#extracting column names
data.columns
# Out:
# Index(['PDT', 'Max TemperatureF', 'Mean TemperatureF', 'Min TemperatureF',
#        'Max Dew PointF', 'MeanDew PointF', 'Min DewpointF', 'Max Humidity',
#        ' Mean Humidity', ' Min Humidity', ' Max Sea Level PressureIn',
#        ' Mean Sea Level PressureIn', ' Min Sea Level PressureIn',
#        ' Max VisibilityMiles', ' Mean VisibilityMiles', ' Min VisibilityMiles',
#        ' Max Wind SpeedMPH', ' Mean Wind SpeedMPH', ' Max Gust SpeedMPH',
#        'PrecipitationIn', ' CloudCover', ' Events', ' WindDirDegrees', 'ZIP'],
#       dtype='object')

# %%
old_names = ['Max TemperatureF', 'Min TemperatureF', 'Mean TemperatureF', 'Max Dew PointF', 'MeanDew PointF',
             'Min DewpointF', 'Max Humidity',
             ' Mean Humidity', ' Min Humidity', ' Max Sea Level PressureIn', ' Mean Sea Level PressureIn',
             ' Min Sea Level PressureIn', ' Max VisibilityMiles', ' Mean VisibilityMiles',
             ' Min VisibilityMiles', ' Max Wind SpeedMPH', ' Mean Wind SpeedMPH', ' Max Gust SpeedMPH', 'PrecipitationIn',
             ' CloudCover', ' WindDirDegrees', ' Events']

# %%
new_names = ['maxTemp', 'minTemp', 'meanTemp', 'maxDew', 'meanDew', 'minDew', 'maxHum', 'meanHum', 'minHum', 'maxPress',
             'minPress', 'meanPress', 'maxVis', 'meanVis',
             'minVis', 'maxWind', 'meanWind', 'maxGust', 'preIn', 'cloud', 'WindDir', 'events']

# %%
#alloting new names for column
data.rename(columns=dict(zip(old_names, new_names)), inplace=True)

# %%
#checking if names have changed 
data.columns
# Out:
# Index(['PDT', 'maxTemp', 'meanTemp', 'minTemp', 'maxDew', 'meanDew', 'minDew',
#        'maxHum', 'meanHum', 'minHum', 'maxPress', 'minPress', 'meanPress',
#        'maxVis', 'meanVis', 'minVis', 'maxWind', 'meanWind', 'maxGust',
#        'preIn', 'cloud', 'events', 'WindDir', 'ZIP'],
#       dtype='object')

# %%
#deleting 'preIn' column
del data['preIn']

# %%
#checking if column is deleted 
data.head()
# Out:
#         PDT  maxTemp  meanTemp  minTemp  maxDew  meanDew  minDew  maxHum  \
# 0  9/1/2015       75        67       58      58       56      54      84
# 1  9/2/2015       73        68       62      59       56      54      78
# 2  9/3/2015       70        65       60      57       54      50      84
# 3  9/4/2015       72        64       55      52       50      48      77
# 4  9/5/2015       79        65       51      53       48      44      89
#
#    meanHum  minHum  ...  maxVis  meanVis  minVis  maxWind  meanWind  maxGust  \
# 0       67      49  ...    10.0     10.0     6.0       22         9     26.0
# 1       68      57  ...    10.0     10.0    10.0       23        12     26.0
# 2       69      53  ...    10.0     10.0    10.0       18        12     25.0
# 3       61      44  ...    10.0     10.0     7.0       20        10     24.0
# 4       60      30  ...    10.0     10.0    10.0       21         7     24.0
#
#    cloud  events  WindDir    ZIP
# 0      2     NaN      245  94107
# 1      5     NaN      249  94107
# 2      2     NaN      250  94107
# 3      2     NaN      233  94107
# 4      2     NaN      289  94107
#
# [5 rows x 23 columns]

# %%
#Relationship between independent variables
correlation = data.corr()
print(correlation)
# Out:
#             maxTemp  meanTemp   minTemp    maxDew   meanDew    minDew  \
# maxTemp    1.000000  0.940125  0.678734  0.645154  0.558554  0.436042
# meanTemp   0.940125  1.000000  0.885971  0.764664  0.724483  0.626420
# minTemp    0.678734  0.885971  1.000000  0.790401  0.820247  0.771777
# maxDew     0.645154  0.764664  0.790401  1.000000  0.938288  0.804724
# meanDew    0.558554  0.724483  0.820247  0.938288  1.000000  0.929663
# minDew     0.436042  0.626420  0.771777  0.804724  0.929663  1.000000
# maxHum    -0.323488 -0.284374 -0.164895  0.225514  0.282495  0.266307
# meanHum   -0.506837 -0.352826 -0.063600  0.201732  0.311401  0.371920
# minHum    -0.577716 -0.374628 -0.021653  0.122861  0.277905  0.395948
# maxPress  -0.484150 -0.589506 -0.618900 -0.491310 -0.489342 -0.454992
# minPress  -0.428998 -0.531804 -0.568203 -0.458110 -0.447087 -0.407634
# meanPress -0.384130 -0.476611 -0.509441 -0.415846 -0.395611 -0.354125
# maxVis     0.019959  0.028430  0.032458  0.051093  0.070031  0.063176
# meanVis    0.176414  0.133710  0.042889 -0.059145 -0.044842 -0.016236
# minVis     0.316425  0.247996  0.104037 -0.057793 -0.046464 -0.024749
# maxWind    0.029427  0.110580  0.192041  0.075218  0.102002  0.100896
# meanWind  -0.048075  0.099398  0.272923  0.071264  0.154642  0.184882
# maxGust   -0.043366  0.010635  0.057558 -0.118659 -0.087629 -0.066090
# cloud     -0.418105 -0.227999  0.071834  0.074641  0.158903  0.202692
# events    -0.435553 -0.349360 -0.167208 -0.078614 -0.090650 -0.091937
# WindDir    0.319936  0.323552  0.270226  0.225192  0.220089  0.182138
# ZIP        0.125062  0.077658 -0.012145 -0.035298 -0.020468 -0.032939
#
#              maxHum   meanHum    minHum  maxPress  ...    maxVis   meanVis  \
# maxTemp   -0.323488 -0.506837 -0.577716 -0.484150  ...  0.019959  0.176414
# meanTemp  -0.284374 -0.352826 -0.374628 -0.589506  ...  0.028430  0.133710
# minTemp   -0.164895 -0.063600 -0.021653 -0.618900  ...  0.032458  0.042889
# maxDew     0.225514  0.201732  0.122861 -0.491310  ...  0.051093 -0.059145
# meanDew    0.282495  0.311401  0.277905 -0.489342  ...  0.070031 -0.044842
# minDew     0.266307  0.371920  0.395948 -0.454992  ...  0.063176 -0.016236
# maxHum     1.000000  0.795565  0.559849  0.167498  ...  0.013712 -0.262709
# meanHum    0.795565  1.000000  0.869155  0.140586  ...  0.014603 -0.277289
# minHum     0.559849  0.869155  1.000000  0.098426  ...  0.032977 -0.251221
# maxPress   0.167498  0.140586  0.098426  1.000000  ... -0.053048 -0.038984
# minPress   0.135380  0.114587  0.081675  0.974824  ... -0.050483 -0.000898
# meanPress  0.113796  0.101785  0.080980  0.916299  ... -0.043830  0.021614
# maxVis     0.013712  0.014603  0.032977 -0.053048  ...  1.000000  0.605318
# meanVis   -0.262709 -0.277289 -0.251221 -0.038984  ...  0.605318  1.000000
# minVis    -0.425035 -0.450178 -0.399053 -0.028783  ...  0.152720  0.695039
# maxWind   -0.088865 -0.071871  0.040545 -0.233319  ...  0.000329 -0.022080
# meanWind  -0.133317 -0.051702  0.160240 -0.284173  ...  0.021638 -0.059580
# maxGust   -0.170693 -0.143342 -0.036093 -0.124676  ... -0.087048 -0.048437
# cloud      0.318643  0.537973  0.626151 -0.017012  ...  0.008145 -0.268528
# events     0.259799  0.364152  0.400835 -0.001740  ... -0.009471 -0.303771
# WindDir   -0.106199 -0.149373 -0.185615 -0.163774  ...  0.040819  0.123177
# ZIP       -0.045838 -0.183317 -0.147836 -0.029220  ... -0.004174 -0.008285
#
#              minVis   maxWind  meanWind   maxGust     cloud    events  \
# maxTemp    0.316425  0.029427 -0.048075 -0.043366 -0.418105 -0.435553
# meanTemp   0.247996  0.110580  0.099398  0.010635 -0.227999 -0.349360
# minTemp    0.104037  0.192041  0.272923  0.057558  0.071834 -0.167208
# maxDew    -0.057793  0.075218  0.071264 -0.118659  0.074641 -0.078614
# meanDew   -0.046464  0.102002  0.154642 -0.087629  0.158903 -0.090650
# minDew    -0.024749  0.100896  0.184882 -0.066090  0.202692 -0.091937
# maxHum    -0.425035 -0.088865 -0.133317 -0.170693  0.318643  0.259799
# meanHum   -0.450178 -0.071871 -0.051702 -0.143342  0.537973  0.364152
# minHum    -0.399053  0.040545  0.160240 -0.036093  0.626151  0.400835
# maxPress  -0.028783 -0.233319 -0.284173 -0.124676 -0.017012 -0.001740
# minPress   0.040264 -0.260552 -0.302414 -0.183776 -0.047552 -0.085642
# meanPress  0.074231 -0.270808 -0.298899 -0.222475 -0.053290 -0.133869
# maxVis     0.152720  0.000329  0.021638 -0.087048  0.008145 -0.009471
# meanVis    0.695039 -0.022080 -0.059580 -0.048437 -0.268528 -0.303771
# minVis     1.000000 -0.032875 -0.065516 -0.097400 -0.427162 -0.570851
# maxWind   -0.032875  1.000000  0.661188  0.515583  0.116200  0.132333
# meanWind  -0.065516  0.661188  1.000000  0.481218  0.254868  0.175897
# maxGust   -0.097400  0.515583  0.481218  1.000000  0.146824  0.218430
# cloud     -0.427162  0.116200  0.254868  0.146824  1.000000  0.512588
# events    -0.570851  0.132333  0.175897  0.218430  0.512588  1.000000
# WindDir    0.174858  0.046028 -0.023984 -0.056870 -0.251200 -0.250181
# ZIP       -0.016294  0.073100  0.067145  0.162762  0.071468  0.023796
#
#             WindDir       ZIP
# maxTemp    0.319936  0.125062
# meanTemp   0.323552  0.077658
# minTemp    0.270226 -0.012145
# maxDew     0.225192 -0.035298
# meanDew    0.220089 -0.020468
# minDew     0.182138 -0.032939
# maxHum    -0.106199 -0.045838
# meanHum   -0.149373 -0.183317
# minHum    -0.185615 -0.147836
# maxPress  -0.163774 -0.029220
# minPress  -0.131672 -0.033788
# meanPress -0.106490 -0.032185
# maxVis     0.040819 -0.004174
# meanVis    0.123177 -0.008285
# minVis     0.174858 -0.016294
# maxWind    0.046028  0.073100
# meanWind  -0.023984  0.067145
# maxGust   -0.056870  0.162762
# cloud     -0.251200  0.071468
# events    -0.250181  0.023796
# WindDir    1.000000 -0.018918
# ZIP       -0.018918  1.000000
#
# [22 rows x 22 columns]

# %% [markdown]
# ### 3. Data visualization

# %%
#selective extraction
data = data[(data['maxTemp'] <= 110) & (data['minTemp'] >= 25)]

# %%
df2 = pd.DataFrame(data, columns=['ZIP'])
u = df2.drop_duplicates(['ZIP'])

# %%
#zipcodes of places in bay region of San Francisco
zipcodes = [94107, 94063, 94301, 94041, 95113]

# %%
#intializing labels 
x = [30, 61, 91, 122, 153, 182, 213, 243, 274, 304, 335, 366]
labels = ['September','October','November','December','January','February','March','April','May','June','July','August']

# %%
plt.figure()
for zcode in zipcodes:
  local = data.loc[data['ZIP'] == zcode]
  df1 = pd.DataFrame(local, columns=['meanTemp'])
  plt.plot(df1.values, '-', label=str(zcode))
  plt.xticks(x,labels,rotation='vertical',fontsize=10)
plt.grid(True)
plt.xlabel('Month')
plt.ylabel('Temperature in Fahrenheit scale', fontsize=10)
plt.title('Fahrenheit Mean Temperature on Bay Area Cities',fontsize=15)
plt.legend(["San Francisco", "San Mateo","Santa Clara", "Mountain View","San Jose"])
plt.show()

# %%
plt.figure()
for zcode in zipcodes:
    mw = data.loc[data['ZIP'] == zcode]
    df3 = pd.DataFrame(mw, columns=['meanWin', 'maxGust'])
    plt.plot(df3.values,'-', label=str(zcode))

plt.xticks(x,labels,rotation='vertical', fontsize=12)
plt.grid(True)
plt.xlabel('Month')
plt.ylabel('MPH', fontsize=15)
plt.title('Mean Wind and Max Gust', fontsize=20)
plt.legend(["Mean Wind","Max Gust"])
plt.show()

# %%
sf = data.loc[data['ZIP'] == 94107]
plt.figure()
df4 = pd.DataFrame(sf, columns=['meanTemp','meanHum'])
plt.plot(df4.values, '-')
plt.grid(True)
plt.autoscale()
plt.xlabel('Month')
plt.ylabel('', fontsize=15)
plt.title('Mean Temperature and Mean Humidity for San Francisco',fontsize=18)
plt.xticks(x,labels,rotation='vertical', fontsize=12)
plt.legend(["Mean Temperature[F]", "Mean Humidity[%]"], fontsize=15)
plt.show()

# %%
data.fillna(0, inplace=True)

# %%
plot_hist = plt.hist(data['meanTemp'], bins=10)
plt.xlabel('Temperature [F]', fontsize=15)
plt.ylabel('Amount', fontsize=15)
plt.title('Mean Temperature on San Francisco Bay Area', fontsize=20)
plt.show()

# %%
data['events'].replace(['Rain','Rain-Thunderstorm','Fog','Fog-Rain'],[1,1,0,1],inplace=True)
sf = data.loc[data['ZIP'] == 94107]
df7 = pd.DataFrame(sf, columns=['cloud','events'])
df7.plot.area(stacked=False)
plt.xlabel('Month')
plt.ylabel('Cloud Level', fontsize=18)
plt.title('Cloud Level with Events: Rain, Storm, Fog etc.',fontsize=20)
plt.xticks(x,labels,rotation='vertical', fontsize=12)
plt.legend(["Cloud","Rain: 1-yes, 0-no"])
plt.show()

# %%
sf = data.loc[data['ZIP'] == 94107]
plt.figure()
df8 = pd.DataFrame(sf, columns=['minPress','meanPress','maxPress'])
plt.plot(df8.values, '-')
plt.grid(True)
plt.autoscale()
plt.xlabel('Month')
plt.ylabel('inHg', fontsize=18)
plt.title('Min, Mean and Max Pressure for San Francisco',fontsize=20)
plt.xticks(x,labels,rotation='vertical', fontsize=12)
plt.legend(["Minimum Pressure", "Mean Pressure","Maximum Pressure"])
plt.show()

# %%
plt.figure()
df9 = pd.DataFrame(sf, columns=['events','meanHum'])
plt.plot(df9, '-')
plt.xlabel('Month')
plt.ylabel('')
plt.title('Plot compare Events such as Rain, Fog etc. with mean Humidity', fontsize=20)
plt.xticks(x,labels,rotation='vertical', fontsize=12)
plt.legend(["Rain?", "Mean Humidity"])
plt.show()

# %%
df10 = pd.DataFrame(sf, columns=['cloud','minVis'])
df10.plot.area(stacked=False)
plt.xlabel('Month')
plt.ylabel('')
plt.title('Plot compare Cloud Level and Mean Visibility', fontsize=20)
plt.xticks(x,labels,rotation='vertical', fontsize=12)
plt.legend(["Cloud Lever","Mean Visibility"])
plt.show()

# %%
print(data)
# Out:
#             PDT  maxTemp  meanTemp  minTemp  maxDew  meanDew  minDew  maxHum  \
# 0      9/1/2015       75        67       58      58       56      54      84
# 1      9/2/2015       73        68       62      59       56      54      78
# 2      9/3/2015       70        65       60      57       54      50      84
# 3      9/4/2015       72        64       55      52       50      48      77
# 4      9/5/2015       79        65       51      53       48      44      89
# ...         ...      ...       ...      ...     ...      ...     ...     ...
# 1825  8/27/2016       78        70       61      56       54      53      72
# 1826  8/28/2016       79        70       60      56       55      54      84
# 1827  8/29/2016       76        68       60      55       54      53      78
# 1828  8/30/2016       81        70       59      56       54      52      78
# 1829  8/31/2016       78        69       60      57       55      52      84
#
#       meanHum  minHum  ...  maxVis  meanVis  minVis  maxWind  meanWind  \
# 0          67      49  ...    10.0     10.0     6.0       22         9
# 1          68      57  ...    10.0     10.0    10.0       23        12
# 2          69      53  ...    10.0     10.0    10.0       18        12
# 3          61      44  ...    10.0     10.0     7.0       20        10
# 4          60      30  ...    10.0     10.0    10.0       21         7
# ...       ...     ...  ...     ...      ...     ...      ...       ...
# 1825       59      46  ...    10.0     10.0    10.0       17         7
# 1826       65      45  ...    10.0     10.0    10.0       17         7
# 1827       64      49  ...    10.0     10.0     8.0       21        10
# 1828       60      42  ...    10.0     10.0    10.0       18         6
# 1829       64      43  ...    10.0     10.0    10.0       20         9
#
#       maxGust  cloud  events  WindDir    ZIP
# 0        26.0      2       0      245  94107
# 1        26.0      5       0      249  94107
# 2        25.0      2       0      250  94107
# 3        24.0      2       0      233  94107
# 4        24.0      2       0      289  94107
# ...       ...    ...     ...      ...    ...
# 1825     20.0      4       0      231  95113
# 1826     21.0      4       0      307  95113
# 1827     26.0      6       0      319  95113
# 1828     23.0      2       0      315  95113
# 1829     24.0      1       0      316  95113
#
# [1827 rows x 23 columns]
